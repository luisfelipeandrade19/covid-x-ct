# %% [markdown]
# # 01. Pré-processamento e Filtro
#
# Este notebook executa o passo crítico de **filtro binário** (Pneumonia vs COVID-19) e o **pré-processamento offline** das imagens.

# %%
import sys
import os

# Adiciona a raiz do projeto ao path para conseguir importar a pasta `src` e `dataset`
sys.path.append(os.path.abspath('..'))

# %% [markdown]
# ### Passo 1: Filtrar arquivos (remover Normal e transformar em binário)

# %%
# Voltamos para a raiz e executamos o módulo via -m para evitar erros de importação
# !cd .. && python -m dataset.prepare_filtered_data

# %% [markdown]
# ### Passo 2: Pré-processamento Offline (CLAHE e recortes)
# Executar o CLAHE online no dataloader deixa o treinamento extremamente lento.
# Aqui processamos as imagens uma única vez e as salvamos, para que o treino possa apenas lê-las prontas.

# %%
# !cd .. && python -m dataset.preprocess
